# %%
import numpy as np
import pandas as pd
import pickle

# %%
df = pickle.load(open('dataset_level2.pkl', 'rb'))

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed    city  \
# 0         5    Australia      England   0.1     0                0  Sydney
# 1         5    Australia      England   0.2     0                0  Sydney
# 2         5    Australia      England   0.3     1                0  Sydney
# 3         5    Australia      England   0.4     1                0  Sydney
# 4         5    Australia      England   0.5     1                0  Sydney
#
#                venue
# 0  Stadium Australia
# 1  Stadium Australia
# 2  Stadium Australia
# 3  Stadium Australia
# 4  Stadium Australia

# %%
# Features required
# batting_team
# bowling_team
# city
# current_score
# ball_left
# wickets_left
# current_rr

# %%
df[df['city'].isnull()]
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0          41  New Zealand    Sri Lanka   0.1     0                0  NaN
# 1          41  New Zealand    Sri Lanka   0.2     0                0  NaN
# 2          41  New Zealand    Sri Lanka   0.3     3                0  NaN
# 3          41  New Zealand    Sri Lanka   0.4     0                0  NaN
# 4          41  New Zealand    Sri Lanka   0.5     0                0  NaN
# ..        ...          ...          ...   ...   ...              ...  ...
# 120       962   Bangladesh     Pakistan  19.2     1                0  NaN
# 121       962   Bangladesh     Pakistan  19.3     0  Shakib Al Hasan  NaN
# 122       962   Bangladesh     Pakistan  19.4     1                0  NaN
# 123       962   Bangladesh     Pakistan  19.5     4                0  NaN
# 124       962   Bangladesh     Pakistan  19.6     0    Nasir Hossain  NaN
#
#                                        venue
# 0    Pallekele International Cricket Stadium
# 1    Pallekele International Cricket Stadium
# 2    Pallekele International Cricket Stadium
# 3    Pallekele International Cricket Stadium
# 4    Pallekele International Cricket Stadium
# ..                                       ...
# 120  Pallekele International Cricket Stadium
# 121  Pallekele International Cricket Stadium
# 122  Pallekele International Cricket Stadium
# 123  Pallekele International Cricket Stadium
# 124  Pallekele International Cricket Stadium
#
# [8671 rows x 8 columns]

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
df['venue'].str.split().apply(lambda x:x[0])
# Out:
# 0      Stadium
# 1      Stadium
# 2      Stadium
# 3      Stadium
# 4      Stadium
#         ...
# 123       Eden
# 124       Eden
# 125       Eden
# 126       Eden
# 127       Eden
# Name: venue, Length: 64741, dtype: object

# %%
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x:x[0]), df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df['city'].unique()
# Out:
# array(['Sydney', 'Johannesburg', 'Nelson', 'Southampton', 'Cape Town',
#        'Dhaka', 'Guwahati', 'London', 'Barbados', 'Hamilton',
#        'Wellington', 'Kolkata', 'Durban', 'Port Elizabeth', 'Chandigarh',
#        'Manchester', 'Chittagong', 'Pallekele', 'Trinidad',
#        'Visakhapatnam', 'Chattogram', 'Cardiff', 'Mirpur', 'St Lucia',
#        'Dehradun', 'Colombo', 'Dubai', 'Adelaide', 'Antigua', 'Lahore',
#        'Dominica', 'Lauderhill', 'Abu Dhabi', 'Auckland', 'Mumbai',
#        'Indore', 'Bengaluru', 'Centurion', 'Chester-le-Street', 'Harare',
#        'Hobart', 'Melbourne', 'Bangalore', 'Kandy', 'Guyana', 'Pune',
#        'Bristol', 'Rajkot', 'Brisbane', 'Delhi', 'Kanpur', 'Lucknow',
#        'Basseterre', 'Hambantota', 'Sylhet', 'Carrara', 'Birmingham',
#        'Karachi', 'Sharjah', 'Mount Maunganui', 'King City', 'Perth',
#        'Providence', 'Nottingham', 'Nagpur', 'Canberra', 'Ahmedabad',
#        'Chennai', 'Nairobi', 'St Kitts', 'Christchurch', 'Hyderabad',
#        'Victoria', 'Thiruvananthapuram', 'Ranchi', 'East London',
#        'Cuttack', 'Jamaica', 'Napier', 'Potchefstroom', 'Dharmasala',
#        'St Vincent', 'Dharamsala', 'Taunton', 'Bloemfontein', 'Paarl',
#        'Gros Islet'], dtype=object)

# %%
# filtering out cities where less than 5 matches were played (less than 600 bowls)
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           5    Australia      England   0.1     0                0
# 1           5    Australia      England   0.2     0                0
# 2           5    Australia      England   0.3     1                0
# 3           5    Australia      England   0.4     1                0
# 4           5    Australia      England   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 123       964  New Zealand        India  19.2     0       MJ Santner
# 124       964  New Zealand        India  19.3     1                0
# 125       964  New Zealand        India  19.4     1                0
# 126       964  New Zealand        India  19.5     2                0
# 127       964  New Zealand        India  19.6     0       TG Southee
#
#          city  current_score
# 0      Sydney              0
# 1      Sydney              0
# 2      Sydney              1
# 3      Sydney              2
# 4      Sydney              3
# ..        ...            ...
# 123  Auckland            154
# 124  Auckland            155
# 125  Auckland            156
# 126  Auckland            158
# 127  Auckland            158
#
# [51109 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           5    Australia      England   0.1     0                0
# 1           5    Australia      England   0.2     0                0
# 2           5    Australia      England   0.3     1                0
# 3           5    Australia      England   0.4     1                0
# 4           5    Australia      England   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 123       964  New Zealand        India  19.2     0       MJ Santner
# 124       964  New Zealand        India  19.3     1                0
# 125       964  New Zealand        India  19.4     1                0
# 126       964  New Zealand        India  19.5     2                0
# 127       964  New Zealand        India  19.6     0       TG Southee
#
#          city  current_score over ball_no
# 0      Sydney              0    0       1
# 1      Sydney              0    0       2
# 2      Sydney              1    0       3
# 3      Sydney              2    0       4
# 4      Sydney              3    0       5
# ..        ...            ...  ...     ...
# 123  Auckland            154   19       2
# 124  Auckland            155   19       3
# 125  Auckland            156   19       4
# 126  Auckland            158   19       5
# 127  Auckland            158   19       6
#
# [51109 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int') * 6) + df['ball_no'].astype('int')
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           5    Australia      England   0.1     0                0
# 1           5    Australia      England   0.2     0                0
# 2           5    Australia      England   0.3     1                0
# 3           5    Australia      England   0.4     1                0
# 4           5    Australia      England   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 123       964  New Zealand        India  19.2     0       MJ Santner
# 124       964  New Zealand        India  19.3     1                0
# 125       964  New Zealand        India  19.4     1                0
# 126       964  New Zealand        India  19.5     2                0
# 127       964  New Zealand        India  19.6     0       TG Southee
#
#          city  current_score over ball_no  balls_bowled
# 0      Sydney              0    0       1             1
# 1      Sydney              0    0       2             2
# 2      Sydney              1    0       3             3
# 3      Sydney              2    0       4             4
# 4      Sydney              3    0       5             5
# ..        ...            ...  ...     ...           ...
# 123  Auckland            154   19       2           116
# 124  Auckland            155   19       3           117
# 125  Auckland            156   19       4           118
# 126  Auckland            158   19       5           119
# 127  Auckland            158   19       6           120
#
# [51109 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           5    Australia      England   0.1     0                0
# 1           5    Australia      England   0.2     0                0
# 2           5    Australia      England   0.3     1                0
# 3           5    Australia      England   0.4     1                0
# 4           5    Australia      England   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 123       964  New Zealand        India  19.2     0       MJ Santner
# 124       964  New Zealand        India  19.3     1                0
# 125       964  New Zealand        India  19.4     1                0
# 126       964  New Zealand        India  19.5     2                0
# 127       964  New Zealand        India  19.6     0       TG Southee
#
#          city  current_score over ball_no  balls_bowled  balls_left
# 0      Sydney              0    0       1             1         119
# 1      Sydney              0    0       2             2         118
# 2      Sydney              1    0       3             3         117
# 3      Sydney              2    0       4             4         116
# 4      Sydney              3    0       5             5         115
# ..        ...            ...  ...     ...           ...         ...
# 123  Auckland            154   19       2           116           4
# 124  Auckland            155   19       3           117           3
# 125  Auckland            156   19       4           118           2
# 126  Auckland            158   19       5           119           1
# 127  Auckland            158   19       6           120           0
#
# [51109 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           5    Australia      England   0.1     0                 0
# 1           5    Australia      England   0.2     0                 0
# 2           5    Australia      England   0.3     1                 0
# 3           5    Australia      England   0.4     1                 0
# 4           5    Australia      England   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 123       964  New Zealand        India  19.2     0                 7
# 124       964  New Zealand        India  19.3     1                 7
# 125       964  New Zealand        India  19.4     1                 7
# 126       964  New Zealand        India  19.5     2                 7
# 127       964  New Zealand        India  19.6     0                 8
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 0      Sydney              0    0       1             1         119
# 1      Sydney              0    0       2             2         118
# 2      Sydney              1    0       3             3         117
# 3      Sydney              2    0       4             4         116
# 4      Sydney              3    0       5             5         115
# ..        ...            ...  ...     ...           ...         ...
# 123  Auckland            154   19       2           116           4
# 124  Auckland            155   19       3           117           3
# 125  Auckland            156   19       4           118           2
# 126  Auckland            158   19       5           119           1
# 127  Auckland            158   19       6           120           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 123             3
# 124             3
# 125             3
# 126             3
# 127             2
#
# [51109 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           5    Australia      England   0.1     0                 0
# 1           5    Australia      England   0.2     0                 0
# 2           5    Australia      England   0.3     1                 0
# 3           5    Australia      England   0.4     1                 0
# 4           5    Australia      England   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 123       964  New Zealand        India  19.2     0                 7
# 124       964  New Zealand        India  19.3     1                 7
# 125       964  New Zealand        India  19.4     1                 7
# 126       964  New Zealand        India  19.5     2                 7
# 127       964  New Zealand        India  19.6     0                 8
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 0      Sydney              0    0       1             1         119
# 1      Sydney              0    0       2             2         118
# 2      Sydney              1    0       3             3         117
# 3      Sydney              2    0       4             4         116
# 4      Sydney              3    0       5             5         115
# ..        ...            ...  ...     ...           ...         ...
# 123  Auckland            154   19       2           116           4
# 124  Auckland            155   19       3           117           3
# 125  Auckland            156   19       4           118           2
# 126  Auckland            158   19       5           119           1
# 127  Auckland            158   19       6           120           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  3.000000
# 4              10  3.600000
# ..            ...       ...
# 123             3  7.965517
# 124             3  7.948718
# 125             3  7.932203
# 126             3  7.966387
# 127             2  7.900000
#
# [51109 rows x 14 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df, on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','runs_x']]

# %%
# shuffling for removing any bias
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 18166   New Zealand  South Africa        Durban             61          81
# 28292      Pakistan     Australia         Dubai             36          86
# 26863     Australia       England   Southampton            209          22
# 11385   Afghanistan         India      St Lucia             34          75
# 48148   New Zealand      Pakistan      Hamilton             28          98
# ...             ...           ...           ...            ...         ...
# 3113    New Zealand       England      St Lucia              0         116
# 48611  South Africa         India  Johannesburg            179          12
# 19203       England  South Africa    Nottingham             97          16
# 7738    West Indies      Pakistan        Mirpur             84          30
# 26231       England         India    Manchester            108          37
#
#        wickets_left        crr  runs_x
# 18166            10   9.384615     151
# 28292             9   6.352941     151
# 26863             8  12.795918     248
# 11385             7   4.533333     115
# 48148             9   7.636364     185
# ...             ...        ...     ...
# 3113             10   0.000000     149
# 48611             7   9.944444     219
# 19203             2   5.596154     111
# 7738              5   5.600000     166
# 26231             5   7.807229     159
#
# [51109 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
# Requirement already satisfied: scipy in /home/abdullah/anaconda3/envs/myenv/lib/python3.9/site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in /home/abdullah/anaconda3/envs/myenv/lib/python3.9/site-packages (from xgboost) (1.21.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.0

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
transform = ColumnTransformer([
    ('trf', OneHotEncoder(sparse=False, drop='first'), 
     ['batting_team', 'bowling_team', 'city'])
],
remainder = 'passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',transform),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)

# %%
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 score:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 2.476540298663434
# R2 score: 0.9616993755584586

# %%
pickle.dump(pipe, open('xgboost_model.pkl', 'wb'))

# %%
for col in ['batting_team', 'bowling_team', 'city']:
    final_df[col] = final_df[col].astype('category')

# %%
X_train.dtypes
# Out:
# batting_team     category
# bowling_team     category
# city             category
# current_score       int64
# balls_left          int64
# wickets_left        int64
# crr               float64
# dtype: object

# %%
import autosklearn.regression

automl = autosklearn.regression.AutoSklearnRegressor(
    time_left_for_this_task=60*5, per_run_time_limit=60, 
    tmp_folder='/tmp/autosklearn_regression_t20_1st_innings_2')

# %%
automl.fit(X_train, y_train, dataset_name='t20_1st_innings')
print(automl.show_models())
# Out:
# [(0.540000, SimpleRegressionPipeline({'data_preprocessor:__choice__': 'feature_type', 'feature_preprocessor:__choice__': 'polynomial', 'regressor:__choice__': 'extra_trees', 'data_preprocessor:feature_type:categorical_transformer:categorical_encoding:__choice__': 'no_encoding', 'data_preprocessor:feature_type:categorical_transformer:category_coalescence:__choice__': 'no_coalescense', 'data_preprocessor:feature_type:numerical_transformer:imputation:strategy': 'most_frequent', 'data_preprocessor:feature_type:numerical_transformer:rescaling:__choice__': 'minmax', 'feature_preprocessor:polynomial:degree': 2, 'feature_preprocessor:polynomial:include_bias': 'False', 'feature_preprocessor:polynomial:interaction_only': 'True', 'regressor:extra_trees:bootstrap': 'True', 'regressor:extra_trees:criterion': 'mse', 'regressor:extra_trees:max_depth': 'None', 'regressor:extra_trees:max_features': 0.9615263480351033, 'regressor:extra_trees:max_leaf_nodes': 'None', 'regressor:extra_trees:min_impurity_decrease': 0.0, 'regressor:extra_trees:min_samples_leaf': 1, 'regressor:extra_trees:min_samples_split': 2, 'regressor:extra_trees:min_weight_fraction_leaf': 0.0},
# dataset_properties={
#   'task': 4,
#   'sparse': False,
#   'multioutput': False,
#   'target_type': 'regression',
#   'signed': False})),
# (0.460000, SimpleRegressionPipeline({'data_preprocessor:__choice__': 'feature_type', 'feature_preprocessor:__choice__': 'select_percentile_regression', 'regressor:__choice__': 'gradient_boosting', 'data_preprocessor:feature_type:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding', 'data_preprocessor:feature_type:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer', 'data_preprocessor:feature_type:numerical_transformer:imputation:strategy': 'mean', 'data_preprocessor:feature_type:numerical_transformer:rescaling:__choice__': 'quantile_transformer', 'feature_preprocessor:select_percentile_regression:percentile': 85.70259306141033, 'feature_preprocessor:select_percentile_regression:score_func': 'f_regression', 'regressor:gradient_boosting:early_stop': 'train', 'regressor:gradient_boosting:l2_regularization': 6.536723381440492e-05, 'regressor:gradient_boosting:learning_rate': 0.03940103065495631, 'regressor:gradient_boosting:loss': 'least_squares', 'regressor:gradient_boosting:max_bins': 255, 'regressor:gradient_boosting:max_depth': 'None', 'regressor:gradient_boosting:max_leaf_nodes': 77, 'regressor:gradient_boosting:min_samples_leaf': 9, 'regressor:gradient_boosting:scoring': 'loss', 'regressor:gradient_boosting:tol': 1e-07, 'data_preprocessor:feature_type:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.0002682359625135144, 'data_preprocessor:feature_type:numerical_transformer:rescaling:quantile_transformer:n_quantiles': 1567, 'data_preprocessor:feature_type:numerical_transformer:rescaling:quantile_transformer:output_distribution': 'uniform', 'regressor:gradient_boosting:n_iter_no_change': 7},
# dataset_properties={
#   'task': 4,
#   'sparse': False,
#   'multioutput': False,
#   'target_type': 'regression',
#   'signed': False})),
# ]

# %%
import sklearn.metrics 

predictions = automl.predict(X_test)
print("R2 score:", sklearn.metrics.r2_score(y_test, predictions))
print("Mean Absolute Error:", sklearn.metrics.mean_absolute_error(y_test, predictions))
# Out:
# Mean Absolute Error: 4.89854557568769

# %%
print(automl.sprint_statistics())
# Out:
# auto-sklearn results:
#   Dataset name: t20_1st_innings
#   Metric: r2
#   Best validation score: 0.930694
#   Number of target algorithm runs: 6
#   Number of successful target algorithm runs: 2
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 0

# %%
pickle.dump(automl, open('automl_model.pkl', 'wb'))

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#      |████████████████████████████████| 173.5 MB 57 kB/s  eta 0:00:01    |██████████████▎                 | 77.7 MB 1.2 MB/s eta 0:01:18
# Requirement already satisfied: numpy in /home/abdullah/anaconda3/envs/myenv/lib/python3.9/site-packages (from xgboost) (1.21.2)
# Requirement already satisfied: scipy in /home/abdullah/anaconda3/envs/myenv/lib/python3.9/site-packages (from xgboost) (1.7.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.0

# %%
import xgboost as xgb
