# %%
# import necessary packages
import numpy as np
import pandas as pd 
from yaml import safe_load 
import os
from tqdm import tqdm

# %%
# get filenames of dataset
filenames = []
for file in os.listdir('dataset'):
    filenames.append(os.path.join('dataset', file))

# %%
# last file is a README.txt file
# make sure to move it from the dataset directory
len(filenames)
# Out:
# 1432

# %%
final_df = pd.DataFrame()
counter = 1 # for indexing dataset
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
# Out:
# 100%|██████████████████████████████████████████| 1432/1432 [06:51<00:00,  3.48it/s]

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Mozambique', 'deliv...                0.9
# 0   [{'1st innings': {'team': 'Cayman Islands', 'd...                0.9
# 0   [{'1st innings': {'team': 'Papua New Guinea', ...                0.9
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
#
#    meta.created  meta.revision       info.city    info.dates info.gender  \
# 0    2020-06-24              1        Gaborone  [2018-08-21]      female
# 0    2019-08-26              1        Hamilton  [2019-08-25]        male
# 0    2015-07-25              1          Dublin  [2015-07-23]        male
# 0    2013-10-01              2             NaN  [2013-09-30]        male
# 0    2014-02-03              1          Sydney  [2014-02-02]        male
# ..          ...            ...             ...           ...         ...
# 0    2019-08-20              1       Rotterdam  [2019-06-23]        male
# 0    2012-09-30              2             NaN  [2012-09-25]        male
# 0    2012-12-27              4  Port Elizabeth  [2012-12-26]        male
# 0    2020-03-28              1        Auckland  [2019-02-08]        male
# 0    2014-11-08              2             NaN  [2014-11-07]      female
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
# 0              T20                   475.0            Botswana  ...
# 0              T20                   866.0             Bermuda  ...
# 0              T20                     NaN         Afghanistan  ...
# 0              T20                     NaN         Afghanistan  ...
# 0              T20                     NaN           Australia  ...
# ..             ...                     ...                 ...  ...
# 0              T20                   808.0         Netherlands  ...
# 0              T20                     NaN            Pakistan  ...
# 0              T20                     NaN        South Africa  ...
# 0              T20                   737.0               India  ...
# 0              T20                     NaN           Australia  ...
#
#                        info.umpires  info.neutral_venue info.outcome.by.runs  \
# 0                               NaN                 NaN                  NaN
# 0              [N Duguid, H Grewal]                 NaN                  NaN
# 0     [GO Brathwaite, AK Chaudhary]                 1.0                  NaN
# 0   [RSA Palliyaguruge, BB Pradhan]                 1.0                106.0
# 0                [SD Fry, P Wilson]                 NaN                 84.0
# ..                              ...                 ...                  ...
# 0        [HKG Jansen, Rizwan Akram]                 NaN                 49.0
# 0              [SJ Davis, IJ Gould]                 1.0                  NaN
# 0         [JD Cloete, AT Holdstock]                 NaN                 33.0
# 0            [CM Brown, WR Knights]                 NaN                  NaN
# 0           [GJ Davidson, AK Wilds]                 NaN                  NaN
#
#    info.outcome.result info.outcome.eliminator info.outcome.method  \
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# ..                 ...                     ...                 ...
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
# 0                  NaN                     NaN                 NaN
#
#     info.supersubs.New Zealand info.supersubs.South Africa info.bowl_out  \
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# ..                         ...                         ...           ...
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
#
#     info.outcome.bowl_out
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# ..                    ...
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
#
# [1432 rows x 28 columns]

# %%
backup = final_df.copy()

# %%
final_df['meta.data_version'].value_counts()
# Out:
# 0.9    1432
# Name: meta.data_version, dtype: int64

# %%
final_df['info.outcome.by.wickets'].value_counts()
# Out:
# 7.0     139
# 6.0     118
# 8.0     101
# 5.0      96
# 9.0      73
# 4.0      50
# 10.0     34
# 3.0      25
# 2.0      18
# 1.0       8
# Name: info.outcome.by.wickets, dtype: int64

# %%
# filtering out redundant columns
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
], inplace=True)

# %%
final_df
# Out:
#                                               innings       info.city  \
# 0   [{'1st innings': {'team': 'Mozambique', 'deliv...        Gaborone
# 0   [{'1st innings': {'team': 'Cayman Islands', 'd...        Hamilton
# 0   [{'1st innings': {'team': 'Papua New Guinea', ...          Dublin
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...             NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...          Sydney
# ..                                                ...             ...
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...       Rotterdam
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...             NaN
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...        Auckland
# 0   [{'1st innings': {'team': 'West Indies', 'deli...             NaN
#
#       info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0   [2018-08-21]      female             T20            Botswana          20
# 0   [2019-08-25]        male             T20             Bermuda          20
# 0   [2015-07-23]        male             T20         Afghanistan          20
# 0   [2013-09-30]        male             T20         Afghanistan          20
# 0   [2014-02-02]        male             T20           Australia          20
# ..           ...         ...             ...                 ...         ...
# 0   [2019-06-23]        male             T20         Netherlands          20
# 0   [2012-09-25]        male             T20            Pakistan          20
# 0   [2012-12-26]        male             T20        South Africa          20
# 0   [2019-02-08]        male             T20               India          20
# 0   [2014-11-07]      female             T20           Australia          20
#
#                          info.teams info.toss.decision  info.toss.winner  \
# 0            [Mozambique, Botswana]                bat        Mozambique
# 0         [Bermuda, Cayman Islands]                bat    Cayman Islands
# 0   [Afghanistan, Papua New Guinea]                bat  Papua New Guinea
# 0              [Afghanistan, Kenya]                bat       Afghanistan
# 0              [Australia, England]                bat         Australia
# ..                              ...                ...               ...
# 0           [Netherlands, Zimbabwe]              field          Zimbabwe
# 0            [Bangladesh, Pakistan]                bat        Bangladesh
# 0       [South Africa, New Zealand]                bat      South Africa
# 0              [New Zealand, India]                bat       New Zealand
# 0          [Australia, West Indies]                bat       West Indies
#
#                                  info.venue  match_id info.player_of_match  \
# 0       Botswana Cricket Association Oval 1         1                  NaN
# 0           White Hill Field, Sandys Parish         2         [AC Douglas]
# 0                     The Village, Malahide         3      [Nawroz Mangal]
# 0                   Sharjah Cricket Stadium         4       [Hamid Hassan]
# 0                         Stadium Australia         5          [GJ Bailey]
# ..                                      ...       ...                  ...
# 0                               Hazelaarweg      1428                  NaN
# 0   Pallekele International Cricket Stadium      1429        [Imran Nazir]
# 0                          St George's Park      1430           [H Davids]
# 0                                 Eden Park      1431          [KH Pandya]
# 0                  Melbourne Cricket Ground      1432          [SR Taylor]
#
#                        info.umpires
# 0                               NaN
# 0              [N Duguid, H Grewal]
# 0     [GO Brathwaite, AK Chaudhary]
# 0   [RSA Palliyaguruge, BB Pradhan]
# 0                [SD Fry, P Wilson]
# ..                              ...
# 0        [HKG Jansen, Rizwan Akram]
# 0              [SJ Davis, IJ Gould]
# 0         [JD Cloete, AT Holdstock]
# 0            [CM Brown, WR Knights]
# 0           [GJ Davidson, AK Wilds]
#
# [1432 rows x 14 columns]

# %%
final_df.columns
# Out:
# Index(['innings', 'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.winner', 'info.overs', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.venue', 'match_id', 'info.player_of_match',
#        'info.umpires'],
#       dtype='object')

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns = ['info.gender'], inplace=True)
final_df
# Out:
# /home/abdullah/anaconda3/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                               innings       info.city  \
# 0   [{'1st innings': {'team': 'Cayman Islands', 'd...        Hamilton
# 0   [{'1st innings': {'team': 'Papua New Guinea', ...          Dublin
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...             NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...          Sydney
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...       Abu Dhabi
# ..                                                ...             ...
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...       Rotterdam
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...       Rotterdam
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...             NaN
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...        Auckland
#
#       info.dates info.match_type info.outcome.winner  info.overs  \
# 0   [2019-08-25]             T20             Bermuda          20
# 0   [2015-07-23]             T20         Afghanistan          20
# 0   [2013-09-30]             T20         Afghanistan          20
# 0   [2014-02-02]             T20           Australia          20
# 0   [2013-11-30]             T20             Ireland          20
# ..           ...             ...                 ...         ...
# 0   [2018-06-12]             T20         Netherlands          20
# 0   [2019-06-23]             T20         Netherlands          20
# 0   [2012-09-25]             T20            Pakistan          20
# 0   [2012-12-26]             T20        South Africa          20
# 0   [2019-02-08]             T20               India          20
#
#                          info.teams info.toss.decision  info.toss.winner  \
# 0         [Bermuda, Cayman Islands]                bat    Cayman Islands
# 0   [Afghanistan, Papua New Guinea]                bat  Papua New Guinea
# 0              [Afghanistan, Kenya]                bat       Afghanistan
# 0              [Australia, England]                bat         Australia
# 0            [Afghanistan, Ireland]                bat           Ireland
# ..                              ...                ...               ...
# 0            [Netherlands, Ireland]              field           Ireland
# 0           [Netherlands, Zimbabwe]              field          Zimbabwe
# 0            [Bangladesh, Pakistan]                bat        Bangladesh
# 0       [South Africa, New Zealand]                bat      South Africa
# 0              [New Zealand, India]                bat       New Zealand
#
#                                  info.venue  match_id info.player_of_match  \
# 0           White Hill Field, Sandys Parish         2         [AC Douglas]
# 0                     The Village, Malahide         3      [Nawroz Mangal]
# 0                   Sharjah Cricket Stadium         4       [Hamid Hassan]
# 0                         Stadium Australia         5          [GJ Bailey]
# 0                      Sheikh Zayed Stadium         7        [DT Johnston]
# ..                                      ...       ...                  ...
# 0                               Hazelaarweg      1427                  NaN
# 0                               Hazelaarweg      1428                  NaN
# 0   Pallekele International Cricket Stadium      1429        [Imran Nazir]
# 0                          St George's Park      1430           [H Davids]
# 0                                 Eden Park      1431          [KH Pandya]
#
#                        info.umpires
# 0              [N Duguid, H Grewal]
# 0     [GO Brathwaite, AK Chaudhary]
# 0   [RSA Palliyaguruge, BB Pradhan]
# 0                [SD Fry, P Wilson]
# 0                [MA Gough, S Ravi]
# ..                              ...
# 0          [AJ Neill, Rizwan Akram]
# 0        [HKG Jansen, Rizwan Akram]
# 0              [SJ Davis, IJ Gould]
# 0         [JD Cloete, AT Holdstock]
# 0            [CM Brown, WR Knights]
#
# [966 rows x 13 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs', 'info.match_type'], inplace=True)
final_df
# Out:
# /home/abdullah/anaconda3/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                               innings       info.city  \
# 0   [{'1st innings': {'team': 'Cayman Islands', 'd...        Hamilton
# 0   [{'1st innings': {'team': 'Papua New Guinea', ...          Dublin
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...             NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...          Sydney
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...       Abu Dhabi
# ..                                                ...             ...
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...       Rotterdam
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...       Rotterdam
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...             NaN
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...        Auckland
#
#       info.dates info.outcome.winner                       info.teams  \
# 0   [2019-08-25]             Bermuda        [Bermuda, Cayman Islands]
# 0   [2015-07-23]         Afghanistan  [Afghanistan, Papua New Guinea]
# 0   [2013-09-30]         Afghanistan             [Afghanistan, Kenya]
# 0   [2014-02-02]           Australia             [Australia, England]
# 0   [2013-11-30]             Ireland           [Afghanistan, Ireland]
# ..           ...                 ...                              ...
# 0   [2018-06-12]         Netherlands           [Netherlands, Ireland]
# 0   [2019-06-23]         Netherlands          [Netherlands, Zimbabwe]
# 0   [2012-09-25]            Pakistan           [Bangladesh, Pakistan]
# 0   [2012-12-26]        South Africa      [South Africa, New Zealand]
# 0   [2019-02-08]               India             [New Zealand, India]
#
#    info.toss.decision  info.toss.winner  \
# 0                 bat    Cayman Islands
# 0                 bat  Papua New Guinea
# 0                 bat       Afghanistan
# 0                 bat         Australia
# 0                 bat           Ireland
# ..                ...               ...
# 0               field           Ireland
# 0               field          Zimbabwe
# 0                 bat        Bangladesh
# 0                 bat      South Africa
# 0                 bat       New Zealand
#
#                                  info.venue  match_id info.player_of_match  \
# 0           White Hill Field, Sandys Parish         2         [AC Douglas]
# 0                     The Village, Malahide         3      [Nawroz Mangal]
# 0                   Sharjah Cricket Stadium         4       [Hamid Hassan]
# 0                         Stadium Australia         5          [GJ Bailey]
# 0                      Sheikh Zayed Stadium         7        [DT Johnston]
# ..                                      ...       ...                  ...
# 0                               Hazelaarweg      1427                  NaN
# 0                               Hazelaarweg      1428                  NaN
# 0   Pallekele International Cricket Stadium      1429        [Imran Nazir]
# 0                          St George's Park      1430           [H Davids]
# 0                                 Eden Park      1431          [KH Pandya]
#
#                        info.umpires
# 0              [N Duguid, H Grewal]
# 0     [GO Brathwaite, AK Chaudhary]
# 0   [RSA Palliyaguruge, BB Pradhan]
# 0                [SD Fry, P Wilson]
# 0                [MA Gough, S Ravi]
# ..                              ...
# 0          [AJ Neill, Rizwan Akram]
# 0        [HKG Jansen, Rizwan Akram]
# 0              [SJ Davis, IJ Gould]
# 0         [JD Cloete, AT Holdstock]
# 0            [CM Brown, WR Knights]
#
# [963 rows x 11 columns]

# %%
import pickle
pickle.dump(final_df, open('dataset_level_1.pkl', 'wb'))

# %%
matches = pickle.load(open('dataset_level_1.pkl', 'rb'))

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'P Manning',
#    'batsman': 'YSD Seneveratne'}},
#  {0.2: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {0.3: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {0.4: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'P Manning'}},
#  {0.5: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {0.6: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {1.1: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {1.2: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {1.3: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {1.4: {'non_striker': 'P Manning',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'YSD Seneveratne'}},
#  {1.5: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {1.6: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {2.1: {'non_striker': 'P Manning',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'YSD Seneveratne'}},
#  {2.2: {'non_striker': 'P Manning',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'YSD Seneveratne'}},
#  {2.3: {'non_striker': 'P Manning',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'YSD Seneveratne'}},
#  {2.4: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {2.5: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {2.6: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'P Manning'}},
#  {3.1: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'YSD Seneveratne'}},
#  {3.2: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'YSD Seneveratne'}},
#  {3.3: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'YSD Seneveratne'}},
#  {3.4: {'non_striker': 'YSD Seneveratne',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {3.5: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'YSD Seneveratne',
#    'wicket': {'player_out': 'YSD Seneveratne',
#     'fielders': ['AC Douglas'],
#     'kind': 'caught'}}},
#  {3.6: {'non_striker': 'OR Willis',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {4.1: {'non_striker': 'P Manning',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {4.2: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'P Manning'}},
#  {4.3: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'P Manning'}},
#  {4.4: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'P Manning'}},
#  {4.5: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {4.6: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {5.1: {'non_striker': 'OR Willis',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {5.2: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {5.3: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {5.4: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'OR Willis'}},
#  {5.5: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {5.6: {'non_striker': 'P Manning',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {6.1: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'legbyes': 1},
#    'batsman': 'OR Willis'}},
#  {6.2: {'non_striker': 'OR Willis',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {6.3: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {6.4: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {6.5: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {6.6: {'non_striker': 'OR Willis',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {7.1: {'non_striker': 'P Manning',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {7.2: {'non_striker': 'P Manning',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {7.3: {'non_striker': 'OR Willis',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {7.4: {'non_striker': 'OR Willis',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {7.5: {'non_striker': 'P Manning',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {7.6: {'non_striker': 'OR Willis',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {8.1: {'non_striker': 'OR Willis',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {8.2: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {8.3: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {8.4: {'non_striker': 'OR Willis',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {8.5: {'non_striker': 'OR Willis',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Manning'}},
#  {8.6: {'non_striker': 'P Manning',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis'}},
#  {9.1: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {9.2: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning'}},
#  {9.3: {'non_striker': 'OR Willis',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Manning',
#    'wicket': {'player_out': 'P Manning',
#     'fielders': ['AC Douglas'],
#     'kind': 'caught'}}},
#  {9.4: {'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'GM Strydom',
#    'batsman': 'OR Willis'}},
#  {9.5: {'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'non_striker': 'GM Strydom',
#    'batsman': 'OR Willis'}},
#  {9.6: {'non_striker': 'GM Strydom',
#    'bowler': 'DL Brangman',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'OR Willis'}},
#  {10.1: {'non_striker': 'GM Strydom',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'OR Willis',
#    'wicket': {'player_out': 'OR Willis',
#     'fielders': ['JE Pitcher'],
#     'kind': 'caught'}}},
#  {10.2: {'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'C Wright',
#    'batsman': 'GM Strydom'}},
#  {10.3: {'non_striker': 'GM Strydom',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'C Wright'}},
#  {10.4: {'non_striker': 'GM Strydom',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'C Wright'}},
#  {10.5: {'non_striker': 'GM Strydom',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'C Wright',
#    'wicket': {'player_out': 'C Wright', 'kind': 'bowled'}}},
#  {10.6: {'non_striker': 'GM Strydom',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers'}},
#  {11.1: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GM Strydom'}},
#  {11.2: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GM Strydom'}},
#  {11.3: {'non_striker': 'GM Strydom',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'LHB Harrington-Myers'}},
#  {11.4: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GM Strydom'}},
#  {11.5: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'GM Strydom'}},
#  {11.6: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GM Strydom'}},
#  {11.7: {'non_striker': 'GM Strydom',
#    'bowler': 'JE Pitcher',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers'}},
#  {12.1: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GM Strydom'}},
#  {12.2: {'non_striker': 'GM Strydom',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'LHB Harrington-Myers'}},
#  {12.3: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'GM Strydom'}},
#  {12.4: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GM Strydom'}},
#  {12.5: {'non_striker': 'GM Strydom',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers'}},
#  {12.6: {'non_striker': 'GM Strydom',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'LHB Harrington-Myers'}},
#  {13.1: {'non_striker': 'GM Strydom',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers'}},
#  {13.2: {'non_striker': 'GM Strydom',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'LHB Harrington-Myers'}},
#  {13.3: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'GM Strydom'}},
#  {13.4: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GM Strydom'}},
#  {13.5: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GM Strydom'}},
#  {13.6: {'non_striker': 'GM Strydom',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'LHB Harrington-Myers'}},
#  {14.1: {'non_striker': 'GM Strydom',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers'}},
#  {14.2: {'non_striker': 'GM Strydom',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'LHB Harrington-Myers'}},
#  {14.3: {'non_striker': 'GM Strydom',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'LHB Harrington-Myers'}},
#  {14.4: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GM Strydom'}},
#  {14.5: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GM Strydom'}},
#  {14.6: {'non_striker': 'GM Strydom',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers'}},
#  {15.1: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GM Strydom',
#    'wicket': {'player_out': 'GM Strydom',
#     'fielders': ['AC Douglas'],
#     'kind': 'caught'}}},
#  {15.2: {'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'non_striker': 'T Taylor',
#    'batsman': 'LHB Harrington-Myers'}},
#  {15.3: {'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'T Taylor',
#    'batsman': 'LHB Harrington-Myers'}},
#  {15.4: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'T Taylor'}},
#  {15.5: {'non_striker': 'LHB Harrington-Myers',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'T Taylor'}},
#  {15.6: {'non_striker': 'T Taylor',
#    'bowler': 'DC Stovell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'LHB Harrington-Myers',
#    'wicket': {'player_out': 'LHB Harrington-Myers', 'kind': 'run out'}}},
#  {16.1: {'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'AF Ifill',
#    'batsman': 'T Taylor'}},
#  {16.2: {'non_striker': 'T Taylor',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'AF Ifill'}},
#  {16.3: {'non_striker': 'AF Ifill',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'T Taylor'}},
#  {16.4: {'non_striker': 'AF Ifill',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'T Taylor'}},
#  {16.5: {'non_striker': 'AF Ifill',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'T Taylor'}},
#  {16.6: {'non_striker': 'T Taylor',
#    'bowler': 'OGL Bascome',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'AF Ifill'}},
#  {17.1: {'non_striker': 'T Taylor',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'AF Ifill'}},
#  {17.2: {'non_striker': 'AF Ifill',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'T Taylor'}},
#  {17.3: {'non_striker': 'AF Ifill',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'T Taylor'}},
#  {17.4: {'non_striker': 'AF Ifill',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'T Taylor',
#    'wicket': {'player_out': 'T Taylor',
#     'fielders': ['DC Stovell'],
#     'kind': 'caught'}}},
#  {17.5: {'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Z McLaughlin',
#    'batsman': 'AF Ifill'}},
#  {17.6: {'non_striker': 'Z McLaughlin',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AF Ifill',
#    'wicket': {'player_out': 'AF Ifill', 'kind': 'bowled'}}},
#  {18.1: {'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'KR Ebanks',
#    'batsman': 'Z McLaughlin'}},
#  {18.2: {'non_striker': 'Z McLaughlin',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'KR Ebanks'}},
#  {18.3: {'non_striker': 'Z McLaughlin',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'KR Ebanks',
#    'wicket': {'player_out': 'KR Ebanks',
#     'fielders': ['OGL Bascome'],
#     'kind': 'caught'}}},
#  {18.4: {'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'A Morris',
#    'batsman': 'Z McLaughlin'}},
#  {18.5: {'non_striker': 'Z McLaughlin',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'A Morris'}},
#  {18.6: {'non_striker': 'A Morris',
#    'bowler': 'RJ Trott',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Z McLaughlin'}},
#  {19.1: {'non_striker': 'Z McLaughlin',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'A Morris'}},
#  {19.2: {'non_striker': 'Z McLaughlin',
#    'bowler': 'AC Douglas',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'A Morris',
#    'wicket': {'player_out': 'A Morris',
#     'fielders': ['JE Pitcher'],
#     'kind': 'caught'}}}]

# %%
matches.iloc[75]
# Out:
# innings                 [{'1st innings': {'team': 'Sri Lanka', 'delive...
# info.city                                                      Hambantota
# info.dates                                                   [2012-09-18]
# info.outcome.winner                                             Sri Lanka
# info.teams                                          [Sri Lanka, Zimbabwe]
# info.toss.decision                                                  field
# info.toss.winner                                                 Zimbabwe
# info.venue              Mahinda Rajapaksa International Cricket Stadiu...
# match_id                                                              112
# info.player_of_match                                         [BAW Mendis]
# info.umpires                                        [IJ Gould, RJ Tucker]
# Name: 0, dtype: object

# %%
count = 1
delivery_df = pd.DataFrame()

for index, row in matches.iterrows():
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl, axis = 1)

# %%
delivery_df
# Out:
#      match_id                      teams    batting_team  ball  \
# 0           2  [Bermuda, Cayman Islands]  Cayman Islands   0.1
# 1           2  [Bermuda, Cayman Islands]  Cayman Islands   0.2
# 2           2  [Bermuda, Cayman Islands]  Cayman Islands   0.3
# 3           2  [Bermuda, Cayman Islands]  Cayman Islands   0.4
# 4           2  [Bermuda, Cayman Islands]  Cayman Islands   0.5
# ..        ...                        ...             ...   ...
# 123       964       [New Zealand, India]     New Zealand  19.2
# 124       964       [New Zealand, India]     New Zealand  19.3
# 125       964       [New Zealand, India]     New Zealand  19.4
# 126       964       [New Zealand, India]     New Zealand  19.5
# 127       964       [New Zealand, India]     New Zealand  19.6
#
#              batsman    bowler  runs player_dismissed      city  \
# 0    YSD Seneveratne  RJ Trott     1                0  Hamilton
# 1          P Manning  RJ Trott     0                0  Hamilton
# 2          P Manning  RJ Trott     0                0  Hamilton
# 3          P Manning  RJ Trott     4                0  Hamilton
# 4          P Manning  RJ Trott     0                0  Hamilton
# ..               ...       ...   ...              ...       ...
# 123       MJ Santner  KK Ahmed     0       MJ Santner  Auckland
# 124       TG Southee  KK Ahmed     1                0  Auckland
# 125    SC Kuggeleijn  KK Ahmed     1                0  Auckland
# 126       TG Southee  KK Ahmed     2                0  Auckland
# 127       TG Southee  KK Ahmed     0       TG Southee  Auckland
#
#                                venue bowling_team
# 0    White Hill Field, Sandys Parish      Bermuda
# 1    White Hill Field, Sandys Parish      Bermuda
# 2    White Hill Field, Sandys Parish      Bermuda
# 3    White Hill Field, Sandys Parish      Bermuda
# 4    White Hill Field, Sandys Parish      Bermuda
# ..                               ...          ...
# 123                        Eden Park        India
# 124                        Eden Park        India
# 125                        Eden Park        India
# 126                        Eden Park        India
# 127                        Eden Park        India
#
# [116547 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Cayman Islands', 'Papua New Guinea', 'Afghanistan', 'Australia',
#        'Ireland', 'West Indies', 'New Zealand', 'England', 'Bangladesh',
#        'South Africa', 'United Arab Emirates', 'Pakistan', 'India',
#        'Kenya', 'Hong Kong', 'Sri Lanka', 'Netherlands', 'Canada',
#        'United States of America', 'Guernsey', 'Jersey', 'Zimbabwe',
#        'Gibraltar', 'Bulgaria', 'Maldives', 'Oman', 'Nepal',
#        'Isle of Man', 'Scotland', 'Romania', 'Malaysia', 'Botswana',
#        'Bhutan', 'Nigeria', 'Vanuatu', 'Thailand', 'Bermuda', 'Singapore',
#        'Ghana', 'Philippines', 'Denmark', 'Germany', 'Kuwait', 'Namibia',
#        'Italy', 'Belgium', 'Spain', 'Uganda', 'Portugal', 'Norway',
#        'Qatar', 'Iran'], dtype=object)

# %%
top_teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(top_teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(top_teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball        batsman     bowler  runs  \
# 0           5    Australia   0.1       CL White  SCJ Broad     0
# 1           5    Australia   0.2       CL White  SCJ Broad     0
# 2           5    Australia   0.3       CL White  SCJ Broad     1
# 3           5    Australia   0.4       AJ Finch  SCJ Broad     1
# 4           5    Australia   0.5       CL White  SCJ Broad     1
# ..        ...          ...   ...            ...        ...   ...
# 123       964  New Zealand  19.2     MJ Santner   KK Ahmed     0
# 124       964  New Zealand  19.3     TG Southee   KK Ahmed     1
# 125       964  New Zealand  19.4  SC Kuggeleijn   KK Ahmed     1
# 126       964  New Zealand  19.5     TG Southee   KK Ahmed     2
# 127       964  New Zealand  19.6     TG Southee   KK Ahmed     0
#
#     player_dismissed      city              venue bowling_team
# 0                  0    Sydney  Stadium Australia      England
# 1                  0    Sydney  Stadium Australia      England
# 2                  0    Sydney  Stadium Australia      England
# 3                  0    Sydney  Stadium Australia      England
# 4                  0    Sydney  Stadium Australia      England
# ..               ...       ...                ...          ...
# 123       MJ Santner  Auckland          Eden Park        India
# 124                0  Auckland          Eden Park        India
# 125                0  Auckland          Eden Park        India
# 126                0  Auckland          Eden Park        India
# 127       TG Southee  Auckland          Eden Park        India
#
# [64741 rows x 10 columns]

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'batting_team', 'ball', 'batsman', 'bowler', 'runs',
#        'player_dismissed', 'city', 'venue', 'bowling_team'],
#       dtype='object')

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
